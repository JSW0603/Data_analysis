# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("PremierLeaguePlayersData.csv")
dataset.head()
# Out:
#    Unnamed: 0     id firstname   lastname   age          nationality  height  \
# 0           0  18241      Mark     Yeates  36.0  Republic of Ireland  175 cm
# 1           1  19153    Gareth      Barry  39.0              England  183 cm
# 2           2  19203    Ashley       Cole  41.0              England  176 cm
# 3           3  19417      Liam  Ridgewell  37.0              England  188 cm
# 4           4  50978    Justin      Hoyte  36.0  Trinidad and Tobago  180 cm
#
#   weight  injured  teamID  ... cardsYel  cardsYelRed  cardsRed  penaltyWon  \
# 0  66 kg    False      47  ...      0.0          0.0       0.0         NaN
# 1  78 kg    False      66  ...      0.0          0.0       0.0         NaN
# 2  66 kg    False      42  ...      0.0          0.0       0.0         NaN
# 3  77 kg    False      66  ...      0.0          0.0       0.0         NaN
# 4  68 kg    False      42  ...      0.0          0.0       0.0         NaN
#
# ...
